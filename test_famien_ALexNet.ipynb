# %%
#Importation des bibliothèques nécessaires
import math
from pathlib import Path 
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D 
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
with open("C:\\Users\\Uriel\\Desktop\\TP Thèse Doctoral ML\\1- CNN\\shipsnet.json") as data_file:
    dataset = json.load(data_file) # charger les données
ships = pd.DataFrame(dataset)
ships.head()
# Out:
#                                                 data  labels  \
# 0  [82, 89, 91, 87, 89, 87, 86, 86, 86, 86, 84, 8...       1
# 1  [76, 75, 67, 62, 68, 72, 73, 73, 68, 69, 69, 6...       1
# 2  [125, 127, 129, 130, 126, 125, 129, 133, 132, ...       1
# 3  [102, 99, 113, 106, 96, 102, 105, 105, 103, 10...       1
# 4  [78, 76, 74, 78, 79, 79, 79, 82, 86, 85, 83, 8...       1
#
#                                    locations             scene_ids
# 0    [-118.2254694333423, 33.73803725920789]  20180708_180909_0f47
# 1    [-122.33222866289329, 37.7491755586813]  20170705_180816_103e
# 2  [-118.14283073363218, 33.736016066914175]  20180712_211331_0f06
# 3   [-122.34784341495181, 37.76648707436548]  20170609_180756_103a
# 4   [-122.34852408322172, 37.75878462398653]  20170515_180653_1007

# %%
# On va extraire "data et labels" pour la suite de notre étude
ships = ships[["data","labels"]]
ships.head()
# Out:
#                                                 data  labels
# 0  [82, 89, 91, 87, 89, 87, 86, 86, 86, 86, 84, 8...       1
# 1  [76, 75, 67, 62, 68, 72, 73, 73, 68, 69, 69, 6...       1
# 2  [125, 127, 129, 130, 126, 125, 129, 133, 132, ...       1
# 3  [102, 99, 113, 106, 96, 102, 105, 105, 103, 10...       1
# 4  [78, 76, 74, 78, 79, 79, 79, 82, 86, 85, 83, 8...       1

# %%
# 0 : pour les images avec navire
# 1 : pour les images sans navire

img_ships = ships["labels"].value_counts()[0]
img_no_ships = ships["labels"].value_counts()[1]

# Afficher le nombre d'images 

print("Nombre d'image avec navire: {}".format(img_ships),"\n")
print("Nombre d'image sans navire: {}".format(img_no_ships))
# Out:
# Nombre d'image avec navire: 3000
#
# Nombre d'image sans navire: 1000

# %%
# On va transformer les informations json en tableau numpy 
# et ensuite les assigner comme variables x et y

import numpy as np
x = np.array(dataset["data"]).astype("uint8")
y = np.array(dataset["labels"]).astype("uint8")

x.shape
# Out:
# (4000, 19200)

# %% [markdown]
# Les données actuelles pour chaque image sont une rangée de 19200 points de données aplaties représentant les valeurs RVB de chaque pixel. Nous devons donc les remodeler.
# Après le remodelage, chaque élément de la nouvelle variable x sera constitué,de 3 listes.
# Chacune de ces listes sera constituée des valeurs RVB de chaque pixel pour la longueur et la largeur de l'image.

# %%
x_reshaped = x.reshape([-1, 3, 80, 80]).transpose([0, 2, 3, 1])
x_reshaped.shape
# Out:
# (4000, 80, 80, 3)

# %% [markdown]
# On constate que la variable **y** est constituée des valeurs d'étiquettes, **1** ou **0**.
# Nous allons chercher à les convertir en matrice de classe binaire.

# %%
from tensorflow.keras.utils import to_categorical
y.shape
y_reshaped = to_categorical(y, num_classes = 2)
y_reshaped.shape
# Out:
# (4000, 2)

# %%
y_reshaped
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# ### **Préparation des données d'entraînement et de test**

# %% [markdown]
# **Etape 1** : Normalisation des données x
#
# L'objectif de la normalisation est de modifier les valeurs des colonnes numériques du jeu de données pour utiliser une échelle commune, sans que les différences de plages de valeurs ne soient faussées et sans perte d'informations.

# %%
x_reshaped = x_reshaped / 255

# Normaliser les valeurs RVB du premier pixel de la première image de l'ensemble de données.
x_reshaped[0][0][0]
# Out:
# array([0.32156863, 0.36862745, 0.31372549])

# %%
# Maintenant les données sont prêtes à être divisées en données d'entrainement et de test.

x_train, x_test, y_train, y_test = train_test_split(x_reshaped, y_reshaped, test_size = 0.20, random_state = 42)
x_train, x_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size = 0.20, random_state = 42)

print("x_train shape",x_train.shape)
print("x_test shape",x_test.shape)

print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)

print("y_train shape",x_validation.shape)
print("y_train shape",y_validation.shape)
# Out:
# x_train shape (2560, 80, 80, 3)
# x_test shape (800, 80, 80, 3)
# y_train shape (2560, 2)
# y_test shape (800, 2)
# y_train shape (640, 80, 80, 3)
# y_train shape (640, 2)

# %%
from tensorflow.keras.models import Sequential

#Initialiser le modèle comme étant un modèle séquentiel
model = Sequential()

# 1ère couche de convolution : 96 filtres, taille du noyau 5*5, stride de 4, activation Relu
model.add(Conv2D(96, (5,5), strides=(4,4), activation="relu",input_shape=(80,80,3)))

# 1ère couche de pooling : MaxPooling avesc un noyau de 3*3 et stride de 2
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

# 2ème couche de convolution : 48 filtres, taille du noyau 4*4, padding de 2, activation Relu
model.add(Conv2D(48, (4,4), padding="same", activation="relu"))

# 2ème couche de pooling : MaxPooling avec un noyau de 3*3 et stride de 2
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

# 3ème couche de convolution : 24 filtres, taille du noyau 3*3, padding de 1, activation Relu
model.add(Conv2D(24, (3,3), padding="same", activation="relu"))

# 3ème couche de pooling : MaxPooling avec un noyau de 3*3 et de stride de 2
model.add(MaxPooling2D(pool_size=(3,3), strides=(2,2)))

# Ecraser les caractéristiques pour les connecter pleinement dans les couches suivantes
model.add(Flatten())

# 1ère couche entièrement connectée : 200 neurones, activation Relu
model.add(Dense(200, activation="relu"))

# Dropout pour prevenir l'overfitting
model.add(Dropout(0.5))

# 2ème couche entièrement connectée : 200 neurones, activation Relu
model.add(Dense(200, activation="relu"))

# Dropout pour prevenir l'overfitting
model.add(Dropout(0.5))

# 3ème Couche entièrement connectée : nombre de classe (Ici on a 2 classes)
model.add(Dense(2, activation="softmax"))

#Compiler le modèle
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
# Compiler du modèle
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 19, 19, 96)        7296
#
#  max_pooling2d (MaxPooling2D  (None, 9, 9, 96)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 48)          73776
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 48)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 24)          10392
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 24)         0
#  2D)
#
#  flatten (Flatten)           (None, 24)                0
#
#  dense (Dense)               (None, 200)               5000
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 2)                 402
#
# =================================================================
# Total params: 137,066
# Trainable params: 137,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs = 50, validation_data=(x_validation, y_validation))

#history = model.fit(x_train, y_train, epochs = 30,batch_size=32),
# Out:
# Epoch 1/50
# 80/80 [==============================] - 9s 64ms/step - loss: 0.5288 - accuracy: 0.7570 - val_loss: 0.3293 - val_accuracy: 0.8625
# Epoch 2/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.3011 - accuracy: 0.8707 - val_loss: 0.3088 - val_accuracy: 0.8656
# Epoch 3/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1687 - accuracy: 0.9363 - val_loss: 0.1513 - val_accuracy: 0.9375
# Epoch 4/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1137 - accuracy: 0.9594 - val_loss: 0.1354 - val_accuracy: 0.9469
# Epoch 5/50
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0889 - accuracy: 0.9691 - val_loss: 0.1400 - val_accuracy: 0.9469
# Epoch 6/50
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.1190 - val_accuracy: 0.9578
# Epoch 7/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0616 - accuracy: 0.9809 - val_loss: 0.1376 - val_accuracy: 0.9547
# Epoch 8/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0401 - accuracy: 0.9848 - val_loss: 0.1841 - val_accuracy: 0.9422
# Epoch 9/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0567 - accuracy: 0.9793 - val_loss: 0.1129 - val_accuracy: 0.9594
# Epoch 10/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0368 - accuracy: 0.9863 - val_loss: 0.0895 - val_accuracy: 0.9734
# Epoch 11/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0311 - accuracy: 0.9883 - val_loss: 0.1870 - val_accuracy: 0.9594
# Epoch 12/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0354 - accuracy: 0.9867 - val_loss: 0.1272 - val_accuracy: 0.9594
# Epoch 13/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0284 - accuracy: 0.9891 - val_loss: 0.1153 - val_accuracy: 0.9656
# Epoch 14/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.1024 - val_accuracy: 0.9672
# Epoch 15/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0150 - accuracy: 0.9937 - val_loss: 0.0968 - val_accuracy: 0.9672
# Epoch 16/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0300 - accuracy: 0.9895 - val_loss: 0.1347 - val_accuracy: 0.9563
# Epoch 17/50
# 80/80 [==============================] - 5s 60ms/step - loss: 0.0384 - accuracy: 0.9852 - val_loss: 0.0847 - val_accuracy: 0.9719
# Epoch 18/50
# 80/80 [==============================] - 6s 69ms/step - loss: 0.0181 - accuracy: 0.9922 - val_loss: 0.2142 - val_accuracy: 0.9547
# Epoch 19/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.1227 - val_accuracy: 0.9625
# Epoch 20/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 0.0997 - val_accuracy: 0.9656
# Epoch 21/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0075 - accuracy: 0.9969 - val_loss: 0.0951 - val_accuracy: 0.9703
# Epoch 22/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.1275 - val_accuracy: 0.9703
# Epoch 23/50
# 80/80 [==============================] - 6s 70ms/step - loss: 7.7220e-04 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9719
# Epoch 24/50
# 80/80 [==============================] - 5s 63ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1089 - val_accuracy: 0.9719
# Epoch 25/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9703
# Epoch 26/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.2911 - val_accuracy: 0.9500
# Epoch 27/50
# 80/80 [==============================] - 4s 51ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.1122 - val_accuracy: 0.9766
# Epoch 28/50
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.1018 - val_accuracy: 0.9703
# Epoch 29/50
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9734
# Epoch 30/50
# 80/80 [==============================] - 5s 68ms/step - loss: 9.6917e-04 - accuracy: 0.9996 - val_loss: 0.1282 - val_accuracy: 0.9719
# Epoch 31/50
# 80/80 [==============================] - 6s 73ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.1167 - val_accuracy: 0.9734
# Epoch 32/50
# 80/80 [==============================] - 6s 70ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.1814 - val_accuracy: 0.9703
# Epoch 33/50
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9719
# Epoch 34/50
# 80/80 [==============================] - 6s 74ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1752 - val_accuracy: 0.9734
# Epoch 35/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 0.2988 - val_accuracy: 0.9547
# Epoch 36/50
# 80/80 [==============================] - 5s 64ms/step - loss: 0.0294 - accuracy: 0.9898 - val_loss: 0.1044 - val_accuracy: 0.9750
# Epoch 37/50
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.1212 - val_accuracy: 0.9734
# Epoch 38/50
# 80/80 [==============================] - 4s 53ms/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.1332 - val_accuracy: 0.9734
# Epoch 39/50
# 80/80 [==============================] - 5s 61ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.1990 - val_accuracy: 0.9672
# Epoch 40/50
# 80/80 [==============================] - 5s 65ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.1127 - val_accuracy: 0.9719
# Epoch 41/50
# 80/80 [==============================] - 5s 62ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.1465 - val_accuracy: 0.9703
# Epoch 42/50
# 80/80 [==============================] - 5s 61ms/step - loss: 5.7727e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9750
# Epoch 43/50
# 80/80 [==============================] - 6s 71ms/step - loss: 3.0248e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9750
# Epoch 44/50
# 80/80 [==============================] - 7s 91ms/step - loss: 1.9516e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9750
# Epoch 45/50
# 80/80 [==============================] - 6s 76ms/step - loss: 1.6274e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9766
# Epoch 46/50
# 80/80 [==============================] - 6s 76ms/step - loss: 8.5907e-05 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9750
# Epoch 47/50
# 80/80 [==============================] - 5s 68ms/step - loss: 1.4285e-04 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9734
# Epoch 48/50
# 80/80 [==============================] - 5s 68ms/step - loss: 7.5953e-05 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9750
# Epoch 49/50
# 80/80 [==============================] - 5s 67ms/step - loss: 8.2974e-05 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9750
# Epoch 50/50
# 80/80 [==============================] - 5s 68ms/step - loss: 3.3379e-05 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9750

# %%
model.evaluate(x_test, y_test)
# Out:
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1079 - accuracy: 0.9825
# [0.10793021321296692, 0.9825000166893005]

# %%
# Courbe de perte
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'green',linewidth=3.0)
plt.plot(history.history['val_loss'],'orange',linewidth=3.0)
plt.legend(['Training_loss', 'Validation_loss)'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Courbe de perte(loss)',fontsize=16)

# Courbe de precision(Accuracy)
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'green',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'orange',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Courbe de precision(Accuracy)',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Courbe de precision(Accuracy)')

# %% [markdown]
# **Interpretation**
#
# **Graphe de précision**:
# D’âpres ce graphe on remarque que la précision training et du test augment avec le nombre
# d'époques.
#
# **Graphe d’erreur** :
# Ce graphe montre que l'erreur du training et du test diminue jusqu'à la première époque.
#
# Nous lui avons fait des tests afin d’obtenir des résultats en termes de précision et d’erreur.
# L'implémentation que nous avons proposé permet de détecter les images sans navire et des images avec
# navire avec un taux de précisons élevé et une erreur faible.

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import seaborn as sns

Y_pred = model.predict(x_test)
# Convertir les classes de prédictions en un vecteur chaud.
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convertissez les observations de validation en un vecteur chaud.
Y_true = np.argmax(y_test,axis = 1) 
# Calculer la matrice de confusion

print("\n""Test Accuracy Score : ",metrics.accuracy_score(Y_true, Y_pred_classes),"\n")

confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 

# Plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predictions Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.tight_layout()

plt.show()
# Out:
# 25/25 [==============================] - 1s 12ms/step
#
# Test Accuracy Score :  0.9825

# %% [markdown]
# - TP : indique que les predictions et les valeurs réelles sont positives
# - TN : indique que les prediction et les valeurs réelles sont toutes les deux négatives
# - FP : indique que la prediction positive est contraire à la valeur réelle qui est négative
# - FN : indique que les predictions sont négatives alors que les valeurs réelles sont positives

# %% [markdown]
# **Nous allons tester notre model**

# %%
prediction = model.predict(x_test)
pd.Series(prediction[1], index=["Image sans navire", "Image avec navire"])
# Out:
# 25/25 [==============================] - 0s 13ms/step
# Image sans navire    9.999999e-01
# Image avec navire    3.576606e-14
# dtype: float32

# %%
plt.imshow(x_test[1])
plt.axis("off")
plt.show()
